# %%
import numpy as np
import pandas as pd
from pathlib import Path
import dask
import dask.dataframe as dd
import matplotlib.pyplot as plt

from dask.distributed import Client, LocalCluster
cluster = LocalCluster(dashboard_address=':38787')
client = Client(cluster)#timeout

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:46019' processes=8 threads=32, memory=32.00 GiB>

# %%
def remove_outliers(df, p=1):

    p1 = df.quantile(p * 0.01)
    p99 = df.quantile(1 - p * 0.01)

    # df = df_delta.copy()
    for col in ['permanent_area', 'seasonal_area']:
        df = df.drop(df[df[col] <= p1[col]].index)
        df = df.drop(df[df[col] >= p99[col]].index)

    return df


def calculate_delta(group, p1, p99, basin_level):
    # group = group.reset_index() # needed for drop
    id = group.index[0]
    for col in ['permanent_area', 'seasonal_area']:
        select = (group[col] > p1[col]) & (group[col] < p99[col])
        group = group[select]
        # group = group.drop(index=group[group[col] <= p1[col]].index)
        # group = group.drop(index=group[group[col] >= p99[col]].index)
        
    if group.empty:
        print(f'group with id {id} all filtered out')
        return pd.DataFrame(data=[], columns=['id_bgl', 'start_year', 'basin_level'] + cols_required)
    
    df_2000_2019 = group[ (2000 <= group['aggregation_year']) & (group['aggregation_year']<= 2019)]
    beta_baseline_median = df_2000_2019[cols_required].median()

    arr_delta = []
    for start_year in [2000, 2005, 2010, 2015, 2017]:
        df_5y = group[ (start_year <= group['aggregation_year']) & (group['aggregation_year'] < start_year + 5)]
        gamma_5y_median = df_5y[cols_required].median()
        
        delta = (gamma_5y_median - beta_baseline_median) / (beta_baseline_median + 1e-15) * 100

        delta_cols = list([delta[col].values for col in [cols_required]][0])
        arr_delta.append([id, start_year, basin_level] + delta_cols)

    df_delta = pd.DataFrame(data=arr_delta, columns=['id_bgl', 'start_year', 'basin_level'] + cols_required)
    return df_delta

# %%
p_high
# Out:
# permanent_area    918.007949
# seasonal_area      77.829528
# Name: 0.99, dtype: float64

# %%
p=1
p_low = basin[cols_required].quantile(p * 0.01).compute()
p_high = basin[cols_required].quantile(1 - p * 0.01).compute()

# %%
test = basin.groupby(f'id_bgl_{basin_level}', group_keys=False)
group = test.get_group('1452072_384').compute()

# %%
res = calculate_delta(group, p_low, p_high, basin_level)
res
# Out:
# group with id 1452072_384 all filtered out
# Empty DataFrame
# Columns: [id_bgl, start_year, basin_level, permanent_area, seasonal_area]
# Index: []

# %%
aaa = basin.groupby(f'id_bgl_{basin_level}', group_keys=False)

# %%
aaa.apply?
# Out:
# Signature: aaa.apply(func, *args, **kwargs)
# Docstring:
# Parallel version of pandas GroupBy.apply
#
# This mimics the pandas version except for the following:
#
# 1.  If the grouper does not align with the index then this causes a full
#     shuffle.  The order of rows within each group may not be preserved.
# 2.  Dask's GroupBy.apply is not appropriate for aggregations. For custom
#     aggregations, use :class:`dask.dataframe.groupby.Aggregation`.
#
# .. warning::
#
#    Pandas' groupby-apply can be used to to apply arbitrary functions,
#    including aggregations that result in one row per group. Dask's
#    groupby-apply will apply ``func`` once on each group, doing a shuffle
#    if needed, such that each group is contained in one partition.
#    When ``func`` is a reduction, e.g., you'll end up with one row
#    per group. To apply a custom aggregation with Dask,
#    use :class:`dask.dataframe.groupby.Aggregation`.
#
# Parameters
# ----------
# func: function
#     Function to apply
# args, kwargs : Scalar, Delayed or object
#     Arguments and keywords to pass to the function.
# meta : pd.DataFrame, pd.Series, dict, iterable, tuple, optional
#     An empty ``pd.DataFrame`` or ``pd.Series`` that matches the dtypes
#     and column names of the output. This metadata is necessary for
#     many algorithms in dask dataframe to work.  For ease of use, some
#     alternative inputs are also available. Instead of a ``DataFrame``,
#     a ``dict`` of ``{name: dtype}`` or iterable of ``(name, dtype)``
#     can be provided (note that the order of the names should match the
#     order of the columns). Instead of a series, a tuple of ``(name,
#     dtype)`` can be used. If not provided, dask will try to infer the
#     metadata. This may lead to unexpected results, so providing
#     ``meta`` is recommended. For more information, see
#     ``dask.dataframe.utils.make_meta``.
#
# Returns
# -------
# applied : Series or DataFrame depending on columns keyword
# File:      /pfs/lustrep1/users/zhanghui/scratch/mpc/lib/python3.10/site-packages/dask/dataframe/groupby.py
# Type:      method

# %%
data_dir = Path.home() / 'pz'
cols_required = ['permanent_area', 'seasonal_area', 
                 # 'maybepermanent', 'maybeseasonal'
                ]
arr_mean_std = []


basin_level = 7
url = data_dir / "Reservoirs" / f"basins_level_{basin_level}_ts.csv"
basin = dd.read_csv(url, include_path_column=True).repartition(npartitions=40).set_index(f'id_bgl_{basin_level}')
meta = {'id_bgl': 'object', 'start_year': int, 'basin_level': int}
meta.update({col: 'float16' for col in cols_required})

p=1
p1 = basin[cols_required].quantile(p * 0.01).compute().to_dict()
p99 = basin[cols_required].quantile(1 - p * 0.01).compute().to_dict()

df_delta = basin.groupby(f'id_bgl_{basin_level}', group_keys=False).apply(calculate_delta, p1, p99, basin_level, meta=meta)#.dropna()
df_delta.visualize('test.png')

# df_delta = remove_outliers(df_delta, p=2)

# %time df = df_delta.compute()

# %%
import pandas as pd


df = pd.read_csv("/users/zhanghui/pz/outputs_p1_p96_e15_V2/Pemanent_water/gaul_0_ts_delta_outliers_removed_p2.csv")
df
# Out:
#      Unnamed: 0          id_bgl  start_year basin_level  permanent_area
# 0             0           Abyei        2017      gaul_0      626.531483
# 1             0     Afghanistan        2017      gaul_0       -0.677151
# 2             0        Akrotiri        2017      gaul_0        6.389357
# 3             0      Aksai Chin        2017      gaul_0        8.408092
# 4             0         Albania        2017      gaul_0        5.125107
# ..          ...             ...         ...         ...             ...
# 258           0  Western Sahara        2017      gaul_0       -1.406677
# 259           0           Yemen        2017      gaul_0       27.686779
# 260           0          Zambia        2017      gaul_0       -0.595961
# 261           0        Zimbabwe        2017      gaul_0        2.979791
# 262           0   �land Islands        2017      gaul_0       -0.352594
#
# [263 rows x 5 columns]

# %%
p_low = 2.0
p_high = 98.0

p_low_value = df['permanent_area'].quantile(p_low * 0.01)#.compute()
p_high_value = df['permanent_area'].quantile(p_high * 0.01)#.compute()
for col in ['permanent_area']:
    select = (df[col] > p_low_value) & (df[col] < p_high_value)
    df = df[select]
df
# Out:
#      Unnamed: 0          id_bgl  start_year basin_level  permanent_area
# 1             0     Afghanistan        2017      gaul_0       -0.677151
# 2             0        Akrotiri        2017      gaul_0        6.389357
# 3             0      Aksai Chin        2017      gaul_0        8.408092
# 4             0         Albania        2017      gaul_0        5.125107
# 5             0         Algeria        2017      gaul_0        1.309690
# ..          ...             ...         ...         ...             ...
# 258           0  Western Sahara        2017      gaul_0       -1.406677
# 259           0           Yemen        2017      gaul_0       27.686779
# 260           0          Zambia        2017      gaul_0       -0.595961
# 261           0        Zimbabwe        2017      gaul_0        2.979791
# 262           0   �land Islands        2017      gaul_0       -0.352594
#
# [251 rows x 5 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0  start_year  permanent_area
# count       251.0       251.0      251.000000
# mean          0.0      2017.0        8.971085
# std           0.0         0.0       29.692467
# min           0.0      2017.0      -20.929653
# 25%           0.0      2017.0       -0.546827
# 50%           0.0      2017.0        1.089285
# 75%           0.0      2017.0        7.279933
# max           0.0      2017.0      284.482982

# %%
p_low_value
# Out:
# -24.703719854776406

# %%
df.describe()
# Out:
#        Unnamed: 0  start_year  permanent_area
# count       263.0       263.0    2.630000e+02
# mean          0.0      2017.0    1.236550e+11
# std           0.0         0.0    2.005347e+12
# min           0.0      2017.0   -5.954904e+01
# 25%           0.0      2017.0   -6.365564e-01
# 50%           0.0      2017.0    1.089285e+00
# 75%           0.0      2017.0    7.481085e+00
# max           0.0      2017.0    3.252126e+13

# %%
# save
output_dir = data_dir / "outputs" / "Reservoirs"
output_dir.mkdir(exist_ok=True, parents=True)

df.to_csv(output_dir / f"basins_level_{basin_level}_ts_delta_outliers_removed_p2.csv")

# save hist
import matplotlib.pyplot as plt
for col in cols_required:
    plt.figure()
    plt.hist(df[col], bins=200)
    plt.title(f'basin level: {basin_level}, {col}')
    plt.savefig(output_dir / f"basins_level_{basin_level}_hist_{col}.png")
    plt.close()

# calculate mean and std
row = [basin_level] + list(df[cols_required].mean().values) + list(df[cols_required].std().values)
arr_mean_std.append(row)

col_names = ['basin_level'] + [f'mean_{col}' for col in cols_required] + [f'std_{col}' for col in cols_required]
df_mean_std = pd.DataFrame(data=arr_mean_std, columns=col_names)
df_mean_std.to_csv(output_dir / f"basin_level_{basin_level}_mean_std.csv")

# %%
test
# Out:
#          id_bgl  start_year  basin_level  permanent_area  seasonal_area  \
# 0   1110158_818        2000            7        0.000000       0.000000
# 1   1110158_818        2005            7        0.000000       0.000000
# 2   1110158_818        2010            7        0.000000       0.000000
# 3   1110158_818        2015            7        0.000000     162.256939
# 4   1110158_818        2017            7        0.000000     486.902040
# ..          ...         ...          ...             ...            ...
# 0   9999999_795        2000            7       -0.450870     -89.989281
# 1   9999999_795        2005            7       -0.091466     -89.458994
# 2   9999999_795        2010            7       -0.012561      29.656089
# 3   9999999_795        2015            7        5.139494     141.762622
# 4   9999999_795        2017            7        4.946099     143.584196
#
#     maybepermanent  maybeseasonal
# 0         0.000000       0.000000
# 1         0.000000       0.000000
# 2         0.000000       0.000000
# 3         0.000000       0.000000
# 4         0.000000       0.000000
# ..             ...            ...
# 0        54.396197     105.789938
# 1        24.624058       4.585189
# 2        -3.668857      26.739198
# 3       -99.999868     -99.644431
# 4       -99.999868     -99.162379
#
# [313580 rows x 7 columns]

# %%
df_delta = test


df_delta.to_csv(output_dir / f"basins_level_{basin_level}_ts_delta.csv")
df_delta

df = remove_outliers(df_delta, p=2)
df.to_csv(output_dir / f"basins_level_{basin_level}_ts_delta_outliers_removed_p2.csv")

# save hist
import matplotlib.pyplot as plt
for col in cols_required:
    plt.figure()
    plt.hist(df[col], bins=200)
    plt.title(f'basin level: {basin_level}, {col}')
    plt.savefig(output_dir / f"basins_level_{basin_level}_hist_{col}.png")
    plt.close()

# calculate mean and std
row = [basin_level] + list(df[cols_required].mean().values) + list(df[cols_required].std().values)
arr_mean_std.append(row)

col_names = ['basin_level'] + [f'mean_{col}' for col in cols_required] + [f'std_{col}' for col in cols_required]
df_mean_std = pd.DataFrame(data=arr_mean_std, columns=col_names)
df_mean_std.to_csv(output_dir / f"basin_level_mean_std.csv")

# %%
data_dir = Path.home() / 'pz'

output_dir = data_dir / "Pemanent_water" / "outputs"
output_dir.mkdir(exist_ok=True)

cols_required = ['permanent_area', 'seasonal_area', 'maybepermanent', 'maybeseasonal']
arr_mean_std = []

def remove_outliers(df_delta, p=1):

    p1 = df_delta.quantile(p * 0.01)
    p99 = df_delta.quantile(1 - p * 0.01)

    df = df_delta.copy()
    for col in cols_required:
        df = df.drop(df[df[col] <= p1[col]].index)
        df = df.drop(df[df[col] >= p99[col]].index)

    return df

# %%
def calculate_delta(group, basin_level):
    id = group[f'id_bgl_{basin_level}'].iloc[0]
    df_2000_2019 = group[ (2000 <= group['aggregation_year']) & (group['aggregation_year']<= 2019)]
    beta_baseline_median = df_2000_2019[cols_required].median()

    arr_delta = []
    for start_year in [2000, 2005, 2010, 2015, 2017]:
        df_5y = group[ (start_year <= group['aggregation_year']) & (group['aggregation_year'] < start_year + 5)]
        gamma_5y_median = df_5y[cols_required].median()
        
        delta = (gamma_5y_median - beta_baseline_median) / (beta_baseline_median + 1e-3) * 100

        delta_cols = list([delta[col].values for col in [cols_required]][0])
        arr_delta.append([id, start_year, basin_level] + delta_cols)

    df_delta = pd.DataFrame(data=arr_delta, columns=['id_bgl', 'start_year', 'basin_level'] + cols_required)
    return df_delta

# %%
url = data_dir / "Pemanent_water" / f"basins_level_{7}_ts.csv"
basin = dd.read_csv(url, dtype={'maybepermanent': 'float64', 'permanent_area': 'float64'})
df = basin.groupby(f'id_bgl_{7}').apply(calculate_delta, 7, meta=(None, 'object'))

# %%
df.head()
# Out:
# 2024-01-19 22:51:34,020 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('calculate_delta-a9c0f0e69a206e02188de2042b718e7d', 0))" coro=<Worker.execute() done, defined at /pfs/lustrep1/users/zhanghui/scratch/mpc/lib/python3.10/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.head()
#
# File /pfs/lustrep1/users/zhanghui/scratch/mpc/lib/python3.10/site-packages/dask/dataframe/core.py:1543, in _Frame.head(self, n, npartitions, compute)
#    1541 # No need to warn if we're already looking at all partitions
#    1542 safe = npartitions != self.npartitions
# -> 1543 return self._head(n=n, npartitions=npartitions, compute=compute, safe=safe)
#
# File /pfs/lustrep1/users/zhanghui/scratch/mpc/lib/python3.10/site-packages/dask/dataframe/core.py:1577, in _Frame._head(self, n, npartitions, compute, safe)
#    1572 result = new_dd_object(
#    1573     graph, name, self._meta, [self.divisions[0], self.divisions[npartitions]]
#    1574 )
#    1576 if compute:
# -> 1577     result = result.compute()
#    1578 return result
#
# File /pfs/lustrep1/users/zhanghui/scratch/mpc/lib/python3.10/site-packages/dask/base.py:379, in DaskMethodsMixin.compute(self, **kwargs)
#     355 def compute(self, **kwargs):
#     356     """Compute this dask collection
#     357
#     358     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     377     dask.compute
#     378     """
# --> 379     (result,) = compute(self, traverse=False, **kwargs)
#     380     return result
#
# File /pfs/lustrep1/users/zhanghui/scratch/mpc/lib/python3.10/site-packages/dask/base.py:665, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     662     postcomputes.append(x.__dask_postcompute__())
#     664 with shorten_traceback():
# --> 665     results = schedule(dsk, keys, **kwargs)
#     667 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /opt/cray/pe/python/3.10.10/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /opt/cray/pe/python/3.10.10/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:42423' processes=0 threads=0, memory=0 B>

# %%
futures = []
for basin_level in range(7,9):
    url = data_dir / "Pemanent_water" / f"basins_level_{basin_level}_ts.csv"
    basin = dd.read_csv(url, dtype={'maybepermanent': 'float64', 'permanent_area': 'float64'})
    df = basin.groupby(f'id_bgl_{basin_level}').apply(calculate_delta, args=(basin_level), meta=(None, 'object'))
    
    # df_delta.to_csv(output_dir / f"basins_level_{basin_level}_ts_delta.csv")

    # df = remove_outliers(df_delta, p=2)
    # df.to_csv(output_dir / f"basins_level_{basin_level}_ts_delta_outliers_removed_p2.csv")

    # for col in cols_required:
    #     plt.figure()
    #     plt.hist(df[col], bins=200)
    #     plt.title(f'basin level: {basin_level}, {col}')
    #     plt.savefig(output_dir / f"basins_level_{basin_level}_hist_{col}.png")
    #     plt.close()

    # # calculate mean and std
    # row = [basin_level] + list(df[cols_required].mean().values) + list(df[cols_required].std().values)
    # arr_mean_std.append(row)


    col_names = ['basin_level'] + [f'mean_{col}' for col in cols_required] + [f'std_{col}' for col in cols_required]
    df_mean_std = pd.DataFrame(data=arr_mean_std, columns=col_names)
    df_mean_std.to_csv(output_dir / f"basin_level_mean_std.csv")

    future = client.compute(df)
    futures.append(future)
    
    
    # col_id = f'id_bgl_{basin_level}'
    # ids = basin[col_id].unique()

    # arr_delta = []
    # for start_year in [2000, 2005, 2010, 2015, 2017]:
    #     print(f"basin level: {basin_level}, start year: [{start_year}, {start_year+4}]")
    #     for id in ids:
    #         df = basin[basin[col_id] == id]

    #         # df_2000_2019 = df[ (2000 <= df['aggregation_year']) & (df['aggregation_year']<= 2019)]
    #         # beta_baseline_median = df_2000_2019[cols_required].median()
    #         # print(baseline_median)

    #         df_5y = df[ (start_year <= df['aggregation_year']) & (df['aggregation_year'] < start_year + 5)]
    #         gamma_5y_median = df_5y[cols_required].median()
    #         # print(beta_baseline_median, gamma_5y_median)

    #         delta = (gamma_5y_median - beta_baseline_median) / (beta_baseline_median + 1e-3) * 100

    #         # print(delta)
    #         delta_cols = list([delta[col].values for col in [cols_required]][0])
    #         # print(delta_cols)
    #         arr_delta.append([id, start_year, basin_level] + delta_cols)

    # df_delta = pd.DataFrame(data=arr_delta, columns=['id_bgl', 'start_year', 'basin_level'] + cols_required)
    # df_delta.to_csv(output_dir / f"basins_level_{basin_level}_ts_delta.csv")
    # df_delta

    # df = remove_outliers(df_delta, p=2)
    # df.to_csv(output_dir / f"basins_level_{basin_level}_ts_delta_outliers_removed_p2.csv")

    # save hist
# Out:
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# ...
# 2024-01-19 22:35:37,395 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-01-19 22:35:37,567 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-01-19 22:35:37,600 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# 2024-01-19 22:35:39,045 - distributed.utils_perf - WARNING - full garbage collections took 17% CPU time recently (threshold: 10%)
# 2024-01-19 22:35:39,047 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-01-19 22:35:39,155 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-01-19 22:35:39,215 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# 2024-01-19 22:35:39,672 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# 2024-01-19 22:35:40,936 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# 2024-01-19 22:35:41,020 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# 2024-01-19 22:35:41,248 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-01-19 22:35:41,282 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# 2024-01-19 22:35:41,641 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# 2024-01-19 22:35:42,817 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-01-19 22:35:42,886 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# 2024-01-19 22:35:43,168 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2024-01-19 22:35:43,253 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-01-19 22:35:43,298 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2024-01-19 22:35:43,353 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)

# %%
client.restart()
# Out:
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:19: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# /tmp/ipykernel_82345/2137247973.py:20: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# 2024-01-19 22:38:06,489 - distributed.nanny - WARNING - Worker process still alive after 76.79999908447267 seconds, killing

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import dask
import dask.dataframe as dd

dtypes = {"aggregation_year": 'uint16',"permanent_area": 'float64',"seasonal_area": 'float64',
          "maybepermanent": 'float64',"maybeseasonal": 'float64'
         }

data_dir = Path.home() / 'pz'
cols_required = ['permanent_area', 
                 # 'seasonal_area'
                #  'maybepermanent', 'maybeseasonal'
                ]
arr_mean_std = []

meta = {'id_bgl': 'object', 'start_year': int, 'basin_level': int} #'id_bgl': 'object', 'start_year': int, 'basin_level': int
meta.update({col: 'float16' for col in cols_required})


def calculate_delta(group, basin_level, epision=1e-15):
    # group = group.reset_index() # needed for drop
    id = group.index[0]
    
    df_2000_2019 = group[ (2000 <= group['aggregation_year']) & (group['aggregation_year']<= 2019)]
    beta_baseline_median = df_2000_2019[cols_required].median()

    arr_delta = []
    for start_year in [2000, 2005, 2010, 2015, 2017]:
    # for start_year in [2017]:
        df_5y = group[ (start_year <= group['aggregation_year']) & (group['aggregation_year'] < start_year + 5)]
        gamma_5y_median = df_5y[cols_required].median()
        
        delta = (gamma_5y_median - beta_baseline_median) / (beta_baseline_median + epision) * 100

        delta_cols = list([delta[col].values for col in [cols_required]][0])
        arr_delta.append([id, start_year, basin_level] + delta_cols)

    df_delta = pd.DataFrame(data=arr_delta, columns=['id_bgl', 'start_year', 'basin_level'] + cols_required)
    return df_delta

def remove_outliers(df, p_low, p_high):
    for col in ['permanent_area']:
        select = (df[col] > p_low[col]) & (df[col] < p_high[col])
        # select = (df[col] < p_high[col])
        df = df[select]
        # df = df.drop(index=df[df[col] <= p1[col]].index)
        # df = df.drop(index=df[df[col] >= p99[col]].index)
    return df



# if __name__ == '__main__':
from dask.distributed import Client, LocalCluster
cluster = LocalCluster(dashboard_address=':38787')
client = Client(cluster)#timeout

folder = "Pemanent_water" # Reservoirs, Pemanent_water
epision = 1e-15

p_low = 2 # remove lowest 1%
p_high = 98 # remove highest 4%


output_dir = data_dir / f"outputs_delta" / folder
output_dir.mkdir(exist_ok=True, parents=True)
print(output_dir)

for basin_level in [0, 3, 4, 5, 6, 7, 8]:
    print()
    print(f"basins_level: {basin_level}")

    url = data_dir / folder / f"basins_level_{basin_level}_ts.csv"
    basin = dd.read_csv(url, include_path_column=False, dtype=dtypes).repartition(npartitions=80).set_index(f'id_bgl_{basin_level}')
    

    df_delta = basin.groupby(f'id_bgl_{basin_level}', group_keys=False).apply(calculate_delta, basin_level, epision, meta=meta)
    df_delta = df_delta.compute()
    df_delta.to_csv(output_dir / f"basins_level_{basin_level}_ts_delta.csv")

    # remove the rows where delta > 100, since we assume that this may be caused by the case when  
    df_delta = df_delta[cols_required][df_delta['permanent_area'] <= 100]        
    p_low_value = df_delta[cols_required].quantile(p_low * 0.01)#.compute()
    p_high_value = df_delta[cols_required].quantile(p_high * 0.01)#.compute()

    print(f"--------------------------------- basin_level: {basin_level}-----------------------------------")
    print(f"p_low_value: {p_low_value['permanent_area']}")
    print(f"p_high_value: {p_high_value['permanent_area']}")
    
    df = remove_outliers(df_delta, p_low_value, p_high_value)
    print()
    print(df.describe())
    
    # df_delta.visualize('test.png')
    df.to_csv(output_dir / f"basins_level_{basin_level}_ts_delta_outliers_removed.csv")

    # save hist
    import matplotlib.pyplot as plt
    for col in cols_required:
        plt.figure()
        df[col].plot(kind='hist', logy=True, bins=200)
        plt.title(f'basin level: {basin_level}, {col}')
        plt.savefig(output_dir / f"basins_level_{basin_level}_hist_{col}.png")
        plt.close()

    # calculate mean and std
    row = [basin_level] + list(df[cols_required].mean().values) + list(df[cols_required].std().values)
    arr_mean_std.append(row)

    col_names = ['basin_level'] + [f'mean_{col}' for col in cols_required] + [f'std_{col}' for col in cols_required]
    df_mean_std = pd.DataFrame(data=arr_mean_std, columns=col_names)
    # df_mean_std.to_csv(output_dir / f"basin_level_{basin_level}_mean_std.csv")
    df_mean_std.to_csv(output_dir / f"basin_level_mean_std.csv")
# Out:
# /pfs/lustrep1/users/zhanghui/scratch/mpc/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 38787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 33337 instead
#   warnings.warn(
# /users/zhanghui/pz/outputs_delta/Pemanent_water
#
# basins_level: 0
# --------------------------------- basin_level: 0-----------------------------------
# p_low_value: -42.21583915723282
# p_high_value: 43.126279405577485
#
#        permanent_area
# count     1284.000000
# mean         0.253809
# std          9.543396
# min        -41.933561
# 25%         -1.814605
# 50%          0.000000
# 75%          2.307945
# max         43.093296

# %%
df_delta.describe()
# Out:
#             id_bgl   start_year  basin_level  permanent_area
# count  1390.000000  1390.000000       1390.0    1.390000e+03
# mean    519.352518  2009.400000          0.0    1.332359e+15
# std     309.913417     6.282388          0.0    3.319337e+16
# min       4.000000  2000.000000          0.0   -1.000000e+02
# 25%     248.000000  2005.000000          0.0   -1.819652e+00
# 50%     506.000000  2010.000000          0.0    0.000000e+00
# 75%     756.000000  2015.000000          0.0    3.046036e+00
# max    1098.000000  2017.000000          0.0    9.806131e+17

# %%
p_low_value['permanent_area']
# Out:
# -42.21583915723282

# %%
df
# Out:
#      id_bgl  start_year  basin_level  permanent_area
# 0   111_232        2000            3       -2.410808
# 1   111_232        2005            3       -7.506029
# 2   111_232        2010            3       -8.339972
# 3   111_232        2015            3       24.779156
# 4   111_232        2017            3       24.779156
# ..      ...         ...          ...             ...
# 0   999_795        2000            3       -0.450870
# 1   999_795        2005            3       -0.091466
# 2   999_795        2010            3       -0.012561
# 3   999_795        2015            3        5.139494
# 4   999_795        2017            3        4.946099
#
# [3734 rows x 4 columns]
